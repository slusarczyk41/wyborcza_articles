# %% [markdown]
# ## Read data

# %%
from os import listdir

# %%
comments_batch = []
for file_name in listdir('comments'):
    with open('comments/'+file_name, 'r') as f:
        comments_batch.append(eval(f.read()))

# %% [markdown]
# ## Remove stop words

# %%
from unidecode import unidecode

# %%
with open('polish.stopwords.txt', 'r') as f:
    stop_words = f.read().split('\n')

# %%
comments_batch[1]['row']['comments']['comments']
# Out:
# [{'main_comment': {'id': '100662295',
#    'author': 'antyhipokryta',
#    'date': '04.07.2018, 21:14',
#    'body': 'Poza wszystkim - to ciekawe, że wszyscy prawacy mają takie tępe, dziwaczne i przestraszone ryje. Często też fikuśne bródki czy oprawki okularów. Nieładnie komentować wygląd, ale coś w tym jest, że takiego głupiego prawaka można natychmiast rozpoznać',
#    'upvotes': '25',
#    'downvotes': '1',
#    'suspicious': False},
#   'sub_comments': [{'id': '100662401',
#     'author': 'Niemiec_z_Niemiec',
#     'date': '04.07.2018, 22:27',
#     'reply_to': 'antyhipokryta',
#     'body': 'Ja ich nawet wrzucam do jednego wora razem z niemieckimi prawakami. Całkiem podobni.',
#     'upvotes': '4',
#     'downvotes': '0',
#     'suspicious': False},
#    {'id': '100662439',
#     'author': 'calvados',
#     'date': '04.07.2018, 23:05',
#     'reply_to': 'antyhipokryta',
#     'body': 'Masz rację. Oglądając zdjęcie zastanawiałem się gdzie ten "dżentelmen" wcześniej działał. Mam prawo nie wiedzieć bo nie mieszkam w Polsce a twarz nie grzeszy myślą i jakby przypomina zbójców z Mickiewiczowskiej ballady.',
#     'upvotes': '2',
#     'downvotes': '0',
#     'suspicious': False},
#    {'id': '100662456',
#     'author': 'kryweg',
#     'date': '04.07.2018, 23:35',
#     'reply_to': 'antyhipokryta',
#     'body': 'Muszę Ci przyznać, ze to prawda. Spojrzałam na zdjęcie i zobaczyłam topornego, tępego buca. Oczywiście pisowskiego. Myślę, że ich obowiązkiem jest być brzydszym i głupszym od prezesa. Najlepiej jeszcze - niższym. I dlatego tam taka menażeria osłów.',
#     'upvotes': '3',
#     'downvotes': '0',
#     'suspicious': False},
#    {'id': '100662519',
#     'author': 'bra-tanki',
#     'date': '05.07.2018, 03:55',
#     'reply_to': 'antyhipokryta',
#     'body': 'Ich wygląd nie jest skutkiem przynależności do pislamu,jest powodem.',
#     'upvotes': '0',
#     'downvotes': '0',
#     'suspicious': True}]},
#  {'main_comment': {'id': '100662473',
#    'author': 'gwmacie1',
#    'date': '05.07.2018, 01:45',
#    'body': 'I tak oto panowie prezesi ordynarnie i w glorii prawa Kalego, kradną pieniądze podatników aż furczy. I twierdzą na dodatek, że te pieniądze im się należą, bo oni za nic nie odpowiadają. Biorą cudzą kasę bo tak.... PiS wogóle ma jakiś problem ze spadochroniarzami z PZPR....gdzie się nie obejrzysz tam były towarzysz.',
#    'upvotes': '20',
#    'downvotes': '0',
#    'suspicious': False},
#   'sub_comments': []},
#  {'main_comment': {'id': '100662404',
#    'author': 'korektor11',
#    'date': '04.07.2018, 22:31',
#    'body': '(...) Chłopaki, Problem jest ogólnie taki: Przyjdzie dużo, a pokazać trzeba mało! W. Młynarski - Przeszkolenie kamerzystów  Prawie 40 lat temu...',
#    'upvotes': '18',
#    'downvotes': '0',
#    'suspicious': False},
#   'sub_comments': []},
#  {'main_comment': {'id': '100662502',
#    'author': 'Herrig',
#    'date': '05.07.2018, 03:21',
#    'body': 'Cyt.Cała opozycja sprzeciwiła się przyjęciu sprawozdań KRRiT i RMN. Ich przyjęcie to jednak zwykła formalność.Aż boję pomyśleć ,że tak samo będzie w wyjsciem dzięki pisowskim komuchom Polski z Unii Europejskiej....',
#    'upvotes': '17',
#    'downvotes': '0',
#    'suspicious': True},
#   'sub_comments': []},
#  {'main_comment': {'id': '100663242',
#    'author': 'jolikgd',
#    'date': '05.07.2018, 08:17',
#    'body': 'A propos relacji TVP sprzed SN przypomina się piosenka Wojciecha Młynarskiego o szkoleniu kamerzystów: "hej chłopaki, problem jest ogólnie taki: przyjdzie dużo, a pokazać trzeba mało" Cóż, mamy PRL-bis. A piosenka pasuje jak ulał do dzisiejszych czasów...',
#    'upvotes': '12',
#    'downvotes': '0',
#    'suspicious': False},
#   'sub_comments': []},
#  {'main_comment': {'id': '100663503',
#    'author': 'Odstawiony',
#    'date': '05.07.2018, 09:34',
#    'body': 'Wszyscy porównują TVPiS z TVP z czasów PRL. Pewne że tak powiem, techniki warsztatowe są teraz takie same, jak te kamery zawsze celnie ustawiane ale poziom ogólnie był wtedy znacznie wyższy. Propaganda była mniej nachalna, choć jednostajna, ale nie istniały te "paski kłamstwa" a tacy wyśmiewacze PRL jak Laskowik czy jaśnie pan Pietrzak zażywali sławy właśnie dzięki występom w TVP. Można się też było pośmiać z absurdów scorealu w komediach Barei czy kabarecie Olgi Lipińskiej. Dziś sytuacja nie do pomyślenia aby ktoś w TVP pokpiwał sobie z dobrej zmiany. Nie było dancingowej muzy (disco polo jeszcze nie wynaleziono) ani tureckich seriali. Owszem, była jazda obowiązkowa w postaci radzieckich filmów, głównie wojennych, ale oprócz tego było sporo filmów na przyzwoitym poziomie i polski teatr, zawsze w gwiazdorskich obsadach.',
#    'upvotes': '11',
#    'downvotes': '0',
#    'suspicious': True},
#   'sub_comments': []},
#  {'main_comment': {'id': '100663374',
#    'author': 'emigrand',
#    'date': '05.07.2018, 08:58',
#    'body': 'TVP niedługo zacznie malować trawę na zielono... Powtórka z historii.',
#    'upvotes': '8',
#    'downvotes': '0',
#    'suspicious': False},
#   'sub_comments': []},
#  {'main_comment': {'id': '100662518',
#    'author': 'bra-tanki',
#    'date': '05.07.2018, 03:54',
#    'body': 'Przed sądem ku...zja miała najwięcej kamer.Nawet wieżyczkę strażniczą zbudowali,ale to chyba były kamery monitoringu i inwigilacji ,dla zera with love. Czyli ku...zja ma 100% oglądalności w grupie docelowej. No i co Nielsen? Zatkało?',
#    'upvotes': '8',
#    'downvotes': '0',
#    'suspicious': False},
#   'sub_comments': []},
#  {'main_comment': {'id': '100663129',
#    'author': 'oktagon',
#    'date': '05.07.2018, 07:51',
#    'body': 'Zawsze twierdziłem, ze to postbolszewicka zaraza przyprawiona narodowym socjalizmem. I oni się mienią prawicą. Może jakby zdobyli się na odrobinę chęci i poczytali sobie np. Klub Jagielloński to by zobaczyli na czym polega światła prawica, a tak to tylko zamordyzm.',
#    'upvotes': '6',
#    'downvotes': '0',
#    'suspicious': False},
#   'sub_comments': []},
#  {'main_comment': {'id': '100662629',
#    'author': 'valdec',
#    'date': '05.07.2018, 05:38',
#    'body': 'Zastanawiam się dlaczego Pismeni mają tak paskudne mordy bo trudno te oblicza nazwać twarzami.',
#    'upvotes': '5',
#    'downvotes': '0',
#    'suspicious': False},
#   'sub_comments': []}]

# %%
all_comments = []
for j in comments_batch:
    url = j['row']['comments']['url']
    for main_comment in j['row']['comments']['comments']:
        comment = {
            "url": url,
            "id": main_comment['main_comment']['id'],
            "date": main_comment['main_comment']['date'],
            "author": main_comment['main_comment']['author'],
            "susp" : False,
            "type" : 'main',
            "upvotes": main_comment['main_comment']['upvotes'],
            "downvotes": main_comment['main_comment']['downvotes'],
            "replies": len(main_comment['sub_comments']),
            "length": len(main_comment['main_comment']['body']),
            "words": [],
        }
        
        words = []
        for word in main_comment['main_comment']['body'].split(' '):
            word = word.lower()
            if word not in stop_words:
                comment["words"].append(unidecode(word))
        if len(comment["words"]) != 0:
            comment["susp"] = main_comment['main_comment']["suspicious"]
            all_comments.append(comment)

        for i, sub_comment in enumerate(main_comment['sub_comments']):
            comment = {
            "url": url,
                "id": sub_comment['id'],
                "date": sub_comment['date'],
                "author": sub_comment['author'],
                "susp" : False,
                "type" : 'sub',
                "upvotes": sub_comment['upvotes'],
                "downvotes": sub_comment['downvotes'],
                "replies": len(main_comment['sub_comments']) - i - 1,
                "length": len(sub_comment['body']),
                "words": [],
            }
            
            for word in sub_comment['body'].split(' '):
                word = word.lower()
                if word not in stop_words:
                    comment["words"].append(unidecode(word))
            if len(comment["words"]) != 0:
                comment["susp"] = sub_comment["suspicious"]
                all_comments.append(comment)

# %% [markdown]
# ## Calculate average sentence lenght

# %%
sentence_lengths = []
for comment in all_comments:
    for sentence in " ".join(comment["words"]).split('.'):
        sentence_lengths.append(len(sentence.split(' ')))

# %%
avg_sentence_lenght = round(sum(sentence_lengths) / len(sentence_lengths), 2)

# %%
# How many times the second layer should be smaller then first one
avg_sentence_lenght
# Out:
# 5.33

# %% [markdown]
# ## Calculate average number of sentences in comment

# %%
comments_sentences_count = []
for comment in all_comments:
    comments_sentences_count.append(len(" ".join(comment["words"])[:-1].split('.')))

# %%
avg_sentencte_count = round(sum(comments_sentences_count) / len(comments_sentences_count), 2)

# %%
# How many times the third layer should be smaller
avg_sentencte_count
# Out:
# 2.73

# %% [markdown]
# ### Remove special characters

# %%
from re import sub

# %%
comments = []
for comment in all_comments:
    tmp_comment = comment.copy()
    tmp_comment["words"] = [sub(r"[^a-z]", "", x) for x in comment["words"] if sub(r"[^a-z]", "", x) != '']
    comments.append(tmp_comment)

# %%
comments[0]
# Out:
# {'url': 'http://warszawa.wyborcza.pl/warszawa/7,54420,23819304,bohaterki-z-placu-muranowskiego-zostaly-sprawiedliwymi-wsrod.html',
#  'id': '100787855',
#  'date': '23.08.2018, 23:27',
#  'author': 'gipsi18',
#  'susp': False,
#  'type': 'main',
#  'upvotes': '6',
#  'downvotes': '0',
#  'replies': 0,
#  'length': 131,
#  'words': ['czytajac',
#   'historie',
#   'zastanawiam',
#   'bym',
#   'zrobila',
#   'wystarczyloby',
#   'odwagi',
#   'strasznie',
#   'boje',
#   'nie']}

# %%
len(comments)
# Out:
# 495204

# %%
import pandas as pd

# %%
pd.DataFrame(comments[:300000]).to_csv('processed_comments_1.csv', index = False)

# %%
pd.DataFrame(comments[300000:]).to_csv('processed_comments_2.csv', index = False)

# %% [markdown]
# # Lets visualize those two types: suspicious and normal to see whether there are differences or not

# %%
to_cloud = {
    "susp": [],
    "rest": [],
}
for comment in comments:
    if comment["susp"]:
        for word in comment["words"]:
            to_cloud["susp"].append(word)
    else:
        for word in comment["words"]:
            to_cloud["rest"].append(word)

# %%
from collections import Counter
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %%
word_could_dict = Counter(to_cloud["susp"])
wordcloud = WordCloud(width = 1200, height = 300).generate_from_frequencies(word_could_dict)

plt.figure(figsize=(20,8))
plt.imshow(wordcloud)
plt.axis("off")
# Out:
# (-0.5, 1199.5, 299.5, -0.5)

# %%
word_could_dict=Counter(to_cloud["rest"])
wordcloud = WordCloud(width = 1200, height = 300).generate_from_frequencies(word_could_dict)

plt.figure(figsize=(20,8))
plt.imshow(wordcloud)
plt.axis("off")
# Out:
# (-0.5, 1199.5, 299.5, -0.5)

# %% [markdown]
# ## Perform basic data mining

# %%
import pandas as pd

# %%
df = pd.DataFrame(comments).drop('words', axis = 1).astype(int, errors = 'ignore')

# %%
len(df)
# Out:
# 459805

# %%
df.head(3)
# Out:
#           author               date downvotes         id  length  replies  \
# 0        gipsi18  23.08.2018, 23:27         0  100787855     131        0
# 1        aneka72  24.08.2018, 01:36         0  100787985      12        0
# 2  antyhipokryta  04.07.2018, 21:14         1  100662295     249        4
#
#    susp  type upvotes
# 0     0  main       6
# 1     0  main       5
# 2     0  main      25

# %%
df[['susp', 'date']].groupby('susp').count()
# Out:
#         date
# susp
# 0     413217
# 1      46588

# %%
df[['susp', 'length']]\
    .groupby('susp')\
    .mean()
# Out:
#           length
# susp
# 0     161.405533
# 1     188.447712

# %%
df['upvotes'] = df['upvotes'].astype(int)

df[['susp', 'upvotes']]\
    .groupby('susp')\
    .mean()
# Out:
#         upvotes
# susp
# 0     14.470917
# 1     16.064995

# %%
df['downvotes'] = df['downvotes'].astype(int)

df[['susp', 'downvotes']]\
    .groupby('susp')\
    .mean()
# Out:
#       downvotes
# susp
# 0      1.471331
# 1      1.485082

# %%
df[['susp', 'replies']]\
    .groupby('susp')\
    .mean()
# Out:
#        replies
# susp
# 0     1.269655
# 1     1.312784

# %%
tmp = df[['susp', 'type', 'date']]\
    .groupby(['susp', 'type'])\
    .count()\
    .reset_index()\
    .pivot('susp', 'type', 'date')
tmp['perc'] = round(tmp['main'] / (tmp['main'] + tmp['sub']), 2)
print(tmp)
# Out:
# type    main     sub  perc
# susp
# 0     250913  162304  0.61
# 1      29642   16946  0.64
